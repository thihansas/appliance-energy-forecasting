# %% [markdown]
# # 07 - Model comparison
# Part 8/9: bring every model's forecast together, evaluate on common metrics, and answer the report questions.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / 'src'))

from appliance_energy import config, plotting
import pandas as pd

# %%
forecast_df = pd.read_csv(config.FORECAST_DIR / 'all_forecasts.csv', index_col=0, parse_dates=True)
results_df = pd.read_csv(config.METRICS_DIR / 'model_comparison.csv')
results_df

# %%
plotting.plot_model_comparison_bar(results_df, metric='RMSE')

# %%
test = forecast_df['actual']
plotting.plot_error_diagnostics(test, forecast_df)
