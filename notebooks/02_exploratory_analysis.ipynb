# %% [markdown]
# # 02 - Exploratory analysis
# Part 1: initial plots, seasonal structure, and stationarity tests.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / 'src'))

from appliance_energy import config, data, plotting

# %%
df = data.load_appliance_data()
y = df[config.TARGET]
y.describe()

# %%
plotting.plot_series_overview(y)

# %%
plotting.plot_seasonal_snapshot(y, days=14)

# %%
plotting.plot_acf_pacf(y, lags=72)

# %% [markdown]
# ## Stationarity tests (ADF + KPSS)

# %%
stationarity_df = data.stationarity_report(y, name=config.TARGET)
stationarity_df
